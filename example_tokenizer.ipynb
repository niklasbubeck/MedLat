# %%
from medtok import available_models, get_model, MODEL_REGISTRY



import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST, CIFAR100
from medmnist import PathMNIST
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch.nn.functional as F
from dataset import MergedMedMNIST
from medmnist import INFO



### Prep Dataset ###
tensor_transforms = transforms.Compose(
    [
        transforms.Resize((224,224)),
        transforms.ToTensor(),
    ]
)

# train_set = MergedMedMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="train", transform=tensor_transforms, download=False, size=224)
# test_set = MergedMedMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="test", transform=tensor_transforms, download=False, size=224)

# train_set = PathMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="train", transform=tensor_transforms, download=False, as_rgb=True, size=224)
# test_set = PathMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="test", transform=tensor_transforms, download=False, as_rgb=True, size=224)

train_set = CIFAR100(root=".", train=True, transform=tensor_transforms, download=True)
test_set = CIFAR100(root=".", train=False, transform=tensor_transforms, download=True)

### Set Device ###
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# attention mode is flash

# %%
def train(model,
          train_set,
          test_set,
          batch_size,
          num_epochs,
          evaluation_iterations):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    model = model.to(device)

    trainloader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    testloader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=8)

    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    train_losses = []
    evaluation_losses = []

    steps_per_epoch = len(trainloader)
    total_steps = steps_per_epoch * num_epochs
    step_counter = 0
    train_loss_running = []
    evaluation_loss_running = []

    with tqdm(total=num_epochs, desc="Epochs") as epoch_bar:
        for epoch in range(num_epochs):
            model.train()
            with tqdm(total=steps_per_epoch, desc=f"Epoch {epoch+1}/{num_epochs} | loss: N/A", leave=False) as pbar:
                for images, labels in trainloader:
                    # print(labels)
                    images = images.to(device)

                    recon, extra_loss = model(images)
                    loss = F.mse_loss(recon, images) +  extra_loss
                    # Update tqdm description with current loss value
                    pbar.set_description(f"Epoch {epoch+1}/{num_epochs} | loss: {loss.item():.4f}")

                    train_loss_running.append(loss.item())

                    loss.backward()
                    optimizer.step()
                    optimizer.zero_grad()

                    step_counter += 1
                    pbar.update(1)

                    if step_counter % 10 == 0:
                        break

                    # Evaluate every evaluation_iterations global step
                    if step_counter % evaluation_iterations == 0:
                        model.eval()
                        evaluation_loss_running.clear()
                        example_shown = False
                        with torch.no_grad():
                            for images_eval, labels_eval in testloader:
                                images_eval = images_eval.to(device)
                                recon_eval, _ = model(images_eval)
                                # Compute PSNR loss
                                mse = F.mse_loss(recon_eval, images_eval)
                                # Clamp to avoid log(0); add small epsilon
                                epsilon = 1e-8
                                psnr = 10 * torch.log10(1.0 / (mse + epsilon))
                                loss_eval = psnr
                                evaluation_loss_running.append(loss_eval.item())
                                
                                if not example_shown:

                                    def prep(img):
                                        img = img.detach().cpu()
                                        return img.squeeze(0) if img.shape[0] == 1 else img.permute(1, 2, 0)

                                    inp = prep(images_eval[0])
                                    rec = prep(recon_eval[0])
                                    cmap = "gray" if inp.ndim == 2 else None

                                    fig, axes = plt.subplots(1, 2, figsize=(6, 3))
                                    titles = ["Input", "Reconstruction"]

                                    for ax, data, title in zip(axes, [inp, rec], titles):
                                        ax.imshow(data, cmap=cmap)
                                        ax.set_title(title)
                                        ax.axis("off")

                                    plt.suptitle(f"Eval Example at Step {step_counter}")
                                    plt.tight_layout()
                                    plt.show()

                                    example_shown = True

                        train_loss_val = np.mean(train_loss_running) if train_loss_running else 0.0
                        evaluation_loss_val = np.mean(evaluation_loss_running) if evaluation_loss_running else 0.0
                        train_losses.append(train_loss_val)
                        evaluation_losses.append(evaluation_loss_val)
                        train_loss_running = []
                        model.train()
            if step_counter % 10 == 0:
                break
            epoch_bar.update(1)
            

    print("Final Training Loss", train_losses[-1] if train_losses else "No log")
    print("Final Evaluation Loss", evaluation_losses[-1] if evaluation_losses else "No log")

    return model, train_losses, evaluation_losses

# %%
all_models = available_models()
print(all_models)
f4_models = [name for name in all_models if "f4" in name]
print("All models with 'f4' in the name:", f4_models)

# model_list=[
# "continuous.aekl.f4_d3", "continuous.aekl.f8_d4", "continuous.aekl.f16_d8",
# "continuous.aekl.f4_d8", "continuous.aekl.f4_d16", "continuous.aekl.f4_d32",
# "continuous.aekl.f8_d8", "continuous.aekl.f8_d16", "continuous.aekl.f8_d32",
# "continuous.aekl.f16_d16", "continuous.aekl.f16_d32", "continuous.aekl.f16_d64",
# "continuous.medvae.f8_d16", "continuous.medvae.f8_d32", "continuous.vavae.f8_d16_dinov2", "continuous.vavae.f8_d32_dinov2",
# "discrete.lfq.f4_d10_b10", "discrete.lfq.f8_d14_b14", "discrete.lfq.f16_d18_b18",
# "discrete.bsq.f4_d10_b10", "discrete.bsq.f8_d14_b14", "discrete.bsq.f16_d18_b18",
# "discrete.simple_qinco.f16_d8_e16384", "discrete.simple_qinco.f4_d3_e8192", "discrete.simple_qinco.f8_d4_e16384",
# "discrete.simvq.f16_d8_e16384", "discrete.simvq.f4_d3_e8192", "discrete.simvq.f8_d4_e16384",
# "discrete.vq.f16_d8_e16384", "discrete.vq.f4_d3_e8192", "discrete.vq.f8_d4_e16384",
# "token.maetok.b_128", "token.maetok.b_256", "token.maetok.b_512",
# "token.titok.b_128_e2e", "token.titok.b_256_e2e", "token.titok.b_512_e2e",
# ]

model_list = [
    "discrete.rqvae.f4_d3_e8192",
    "discrete.rqvae.f8_d4_e16384",
    "discrete.rqvae.f16_d8_e16384",
    "token.titok.b_128_p8_e2e", "token.titok.b_256_p8_e2e", "token.titok.b_512_p8_e2e",
    "token.maetok.b_128_p8", "token.maetok.b_256_p8", "token.maetok.b_512_p8",
]

print(model_list.__len__())
for model_name in model_list:
    print(f"Training: ", model_name)
    f4 = get_model(model_name, img_size=224)

    linear_ae, train_losses, evaluation_losses = train(f4,
                                                    train_set=train_set,
                                                    test_set=test_set,
                                                    batch_size=8,
                                                    num_epochs=10,
                                                    evaluation_iterations=1000)
# Out:
# ('adm.classifier.128c', 'adm.classifier.256c', 'adm.classifier.512c', 'adm.classifier.64c', 'adm.diffusion.128c', 'adm.diffusion.128u', 'adm.diffusion.256c', 'adm.diffusion.256u', 'adm.diffusion.512c', 'adm.diffusion.512u', 'adm.diffusion.64c', 'adm.diffusion.64u', 'continuous.aekl.f16_d16', 'continuous.aekl.f16_d32', 'continuous.aekl.f16_d64', 'continuous.aekl.f16_d8', 'continuous.aekl.f32_d64', 'continuous.aekl.f4_d16', 'continuous.aekl.f4_d3', 'continuous.aekl.f4_d32', 'continuous.aekl.f4_d8', 'continuous.aekl.f8_d16', 'continuous.aekl.f8_d32', 'continuous.aekl.f8_d4', 'continuous.aekl.f8_d8', 'continuous.maisi.f4_d3', 'continuous.medvae.f8_d16', 'continuous.medvae.f8_d32', 'continuous.vavae.f16_d16_dinov2', 'continuous.vavae.f16_d16_mae', 'continuous.vavae.f16_d32_dinov2', 'continuous.vavae.f16_d32_mae', 'continuous.vavae.f16_d64_dinov2', 'continuous.vavae.f16_d64_mae', 'continuous.vavae.f8_d16_dinov2', 'continuous.vavae.f8_d32_dinov2', 'discrete.bsq.f16_d10_b10', 'discrete.bsq.f16_d12_b12', 'discrete.bsq.f16_d14_b14', 'discrete.bsq.f16_d16_b16', 'discrete.bsq.f16_d18_b18', 'discrete.bsq.f4_d10_b10', 'discrete.bsq.f4_d12_b12', 'discrete.bsq.f4_d14_b14', 'discrete.bsq.f4_d16_b16', 'discrete.bsq.f4_d18_b18', 'discrete.bsq.f8_d10_b10', 'discrete.bsq.f8_d12_b12', 'discrete.bsq.f8_d14_b14', 'discrete.bsq.f8_d16_b16', 'discrete.bsq.f8_d18_b18', 'discrete.fsq.f16_d256_e10', 'discrete.fsq.f16_d256_e12', 'discrete.fsq.f16_d256_e14', 'discrete.fsq.f16_d256_e16', 'discrete.fsq.f16_d256_e8', 'discrete.fsq.f16_d8_l16384', 'discrete.fsq.f4_d3_l8192', 'discrete.fsq.f8_d4_l16384', 'discrete.lfq.f16_d10_b10', 'discrete.lfq.f16_d12_b12', 'discrete.lfq.f16_d14_b14', 'discrete.lfq.f16_d16_b16', 'discrete.lfq.f16_d18_b18', 'discrete.lfq.f4_d10_b10', 'discrete.lfq.f4_d12_b12', 'discrete.lfq.f4_d14_b14', 'discrete.lfq.f4_d16_b16', 'discrete.lfq.f4_d18_b18', 'discrete.lfq.f8_d10_b10', 'discrete.lfq.f8_d12   _b12', 'discrete.lfq.f8_d14_b14', 'discrete.lfq.f8_d16_b16', 'discrete.lfq.f8_d18_b18', 'discrete.maskgit.vq.f16_d256_e1024', 'discrete.msrq.f16_d32_e4096', 'discrete.quantizer.binary_spherical_quantizer', 'discrete.quantizer.finite_scalar_quantizer', 'discrete.quantizer.grouped_residual_quantizer', 'discrete.quantizer.gumbel_quantizer', 'discrete.quantizer.lookup_free_quantizer', 'discrete.quantizer.msrq_vector_quantizer2', 'discrete.quantizer.residual_quantizer', 'discrete.quantizer.simple_qinco', 'discrete.quantizer.vector_quantizer', 'discrete.quantizer.vector_quantizer2', 'discrete.simple_qinco.f16_d8_e16384', 'discrete.simple_qinco.f4_d3_e8192', 'discrete.simple_qinco.f8_d4_e16384', 'discrete.simvq.f16_d8_e16384', 'discrete.simvq.f4_d3_e8192', 'discrete.simvq.f8_d4_e16384', 'discrete.vq.f16_d16_e16384', 'discrete.vq.f16_d32_e16384', 'discrete.vq.f16_d64_e16384', 'discrete.vq.f16_d8_e16384', 'discrete.vq.f4_d16_e8192', 'discrete.vq.f4_d32_e8192', 'discrete.vq.f4_d3_e8192', 'discrete.vq.f4_d8_e8192', 'discrete.vq.f8_d16_e16384', 'discrete.vq.f8_d32_e16384', 'discrete.vq.f8_d4_e16384', 'discrete.vq.f8_d8_e16384', 'dit.b_1', 'dit.b_2', 'dit.b_4', 'dit.b_8', 'dit.l_1', 'dit.l_2', 'dit.l_4', 'dit.l_8', 'dit.s_1', 'dit.s_2', 'dit.s_4', 'dit.s_8', 'dit.xl_1', 'dit.xl_2', 'dit.xl_4', 'dit.xl_8', 'ldm.f1', 'ldm.f16', 'ldm.f2', 'ldm.f4', 'ldm.f8', 'mar.b', 'mar.h', 'mar.l', 'maskgit.b', 'maskgit.h', 'maskgit.l', 'token.detok.bb', 'token.detok.bl', 'token.detok.bs', 'token.detok.lb', 'token.detok.ll', 'token.detok.ls', 'token.detok.sb', 'token.detok.sl', 'token.detok.ss', 'token.detok.xlxl', 'token.maetok.b_128_p16', 'token.maetok.b_128_p8', 'token.maetok.b_256_p8', 'token.maetok.b_512_p8', 'token.maetok.l_128', 'token.maetok.l_256', 'token.maetok.l_512', 'token.maetok.s_128', 'token.maetok.s_256', 'token.maetok.s_512', 'token.titok.b_128_p8_e2e', 'token.titok.b_256_p8_e2e', 'token.titok.b_512_p8_e2e', 'token.titok.b_64', 'token.titok.l_128_e2e', 'token.titok.l_256_e2e', 'token.titok.l_32', 'token.titok.l_512_e2e', 'token.titok.l_64_e2e', 'token.tit ...
# All models with 'f4' in the name: ['continuous.aekl.f4_d16', 'continuous.aekl.f4_d3', 'continuous.aekl.f4_d32', 'continuous.aekl.f4_d8', 'continuous.maisi.f4_d3', 'discrete.bsq.f4_d10_b10', 'discrete.bsq.f4_d12_b12', 'discrete.bsq.f4_d14_b14', 'discrete.bsq.f4_d16_b16', 'discrete.bsq.f4_d18_b18', 'discrete.fsq.f4_d3_l8192', 'discrete.lfq.f4_d10_b10', 'discrete.lfq.f4_d12_b12', 'discrete.lfq.f4_d14_b14', 'discrete.lfq.f4_d16_b16', 'discrete.lfq.f4_d18_b18', 'discrete.simple_qinco.f4_d3_e8192', 'discrete.simvq.f4_d3_e8192', 'discrete.vq.f4_d16_e8192', 'discrete.vq.f4_d32_e8192', 'discrete.vq.f4_d3_e8192', 'discrete.vq.f4_d8_e8192', 'ldm.f4']
# 6
# Training:  token.titok.b_128_p8_e2e
# num latent tokens: 128
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# Final Training Loss No log
# Final Evaluation Loss No log
# Training:  token.titok.b_256_p8_e2e
# num latent tokens: 256
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# Final Training Loss No log
# Final Evaluation Loss No log
# Training:  token.titok.b_512_p8_e2e
# num latent tokens: 512
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# Final Training Loss No log
# Final Evaluation Loss No log
# Training:  token.maetok.b_128_p8
# Using HOG decoder
# Using DINO decoder
# Using CLIP decoder
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# Final Training Loss No log
# Final Evaluation Loss No log
# Training:  token.maetok.b_256_p8
# Using HOG decoder
# Using DINO decoder
# Using CLIP decoder
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# Final Training Loss No log
# Final Evaluation Loss No log
# Training:  token.maetok.b_512_p8
# Using HOG decoder
# Using DINO decoder
# Using CLIP decoder
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 31
#      28 print(f"Training: ", model_name)
#      29 f4 = get_model(model_name, img_size=224)
# ---> 31 linear_ae, train_losses, evaluation_losses = train(f4,
#      32                                                 train_set=train_set,
#      33                                                 test_set=test_set,
#      34                                                 batch_size=8,
#      35                                                 num_epochs=10,
#      36                                                 evaluation_iterations=1000)
#
# Cell In[2], line 34, in train(model, train_set, test_set, batch_size, num_epochs, evaluation_iterations)
#      30 for images, labels in trainloader:
#      31     # print(labels)
#      32     images = images.to(device)
# ---> 34     recon, extra_loss = model(images)
#      35     loss = F.mse_loss(recon, images) +  extra_loss
#      36     # Update tqdm description with current loss value
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /vol/miltank/users/bubeckn/MedTok/medtok/first_stage/token/maetok/maetok.py:334, in MaskAEModel.forward(self, input)
#     332 # CLIP alignment loss
#     333 if self.aux_clip_decoder is not None:
# --> 334     clip_loss, _ = self.aux_clip_decoder(quant, input_image=input, mask=mask if self.aux_loss_mask else None)
#     335     clip_rec_loss = clip_loss
#     336 else:
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /vol/miltank/users/bubeckn/MedTok/medtok/modules/alignments.py:217, in AlignmentModule.forward(self, quant, input_image, mask)
#     214 self.ensure_projection_dim(target.size(-1))
#     216 # predicted features from decoder/projection
# --> 217 pred = self.decode_projection(quant)  # (B, L_pred, D)
#     219 # Align token grids if lengths differ (e.g., different patch sizes)
#     220 if pred.shape[1] != target.shape[1]:
#
# File /vol/miltank/users/bubeckn/MedTok/medtok/modules/alignments.py:478, in ClipAlignment.decode_projection(self, quant)
#     476 x = self.post_quant_conv(quant)
#     477 if self.clip_use_movq:
# --> 478     dec = self.decoder(x, interpolate_zq=tmp, H=None, W=None, D=None)
#     479 else:
#     480     dec = self.decoder(x, interpolate_zq=None, H=None, W=None, D=None)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /vol/miltank/users/bubeckn/MedTok/medtok/first_stage/token/maetok/modules/vit_models.py:701, in MAETokViTDecoder.forward(self, z, interpolate_zq, H, W, D)
#     699 for i, blk in enumerate(self.blocks):
#     700     if self.use_movq:
# --> 701         x = blk(x, interpolate_zq, rope_tensor=rope_tensor,
#     702                num_prefix_tokens=self.num_prefix_tokens, num_latent_tokens=self.num_latent_tokens)
#     703     else:
#     704         x = blk(x, rope_tensor=rope_tensor, num_prefix_tokens=self.num_prefix_tokens,
#     705                num_latent_tokens=self.num_latent_tokens)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /vol/miltank/users/bubeckn/MedTok/medtok/first_stage/token/maetok/modules/vit_models.py:258, in MoVQBlockv2.forward(self, x, interpolate_zq, attn_mask, rope_tensor, num_prefix_tokens, num_latent_tokens)
#     251 attn_out = self.norm1(x)
#     253 attn_out = torch.cat([
#     254     attn_out[:, :-num_latent_tokens],
#     255     modulate(attn_out[:, -num_latent_tokens:], shift_msa, scale_msa)
#     256 ], dim=1)
# --> 258 attn_out = self.attn(attn_out, attn_mask, rope_tensor=rope_tensor, num_prefix_tokens=num_prefix_tokens, num_latent_tokens=num_latent_tokens)
#     259 x = x + self.drop_path1(attn_out)
#     261 # mlp
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /vol/miltank/users/bubeckn/MedTok/medtok/first_stage/token/maetok/modules/vit_models.py:91, in Attention.forward(self, x, attn_mask, rope_tensor, num_prefix_tokens, num_latent_tokens)
#      88         k = torch.cat([k[:, :, :num_prefix_tokens], k_rot, k[:, :, -num_latent_tokens:]], dim=2)
#      90 q = q * self.scale
# ---> 91 attn = q @ k.transpose(-2, -1)
#      92 attn = attn.softmax(dim=-1)
#      93 attn = self.attn_drop(attn)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 92.00 MiB. GPU 0 has a total capacity of 47.41 GiB of which 44.06 MiB is free. Including non-PyTorch memory, this process has 47.36 GiB memory in use. Of the allocated memory 46.48 GiB is allocated by PyTorch, and 525.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
generated_index = 150
image, label = test_set[generated_index]

# Add batch dimension, move to device
image = image.unsqueeze(0).to(device)

# Forward pass
recon, _ = f4(image)

# Move to CPU, remove batch dim → shape: (C, H, W)
recon = recon.cpu().detach().squeeze()

# Convert to H×W×C (RGB) or H×W (grayscale)
if recon.ndim == 3:                 # C,H,W
    if recon.shape[0] == 1:         # grayscale
        recon = recon.squeeze(0)    # → H,W
        cmap = "gray"
    else:                           # RGB
        recon = recon.permute(1, 2, 0).numpy()
        cmap = None
else:
    cmap = "gray"

plt.imshow(recon, cmap=cmap)
plt.title("RVQVAE")
plt.axis("off")
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.058136705..0.31163618].
